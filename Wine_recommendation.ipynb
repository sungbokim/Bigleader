# %% [markdown]
# <a href="https://colab.research.google.com/github/sungbokim/Bigleader/blob/main/Wine_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine_data.csv")

# %%
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df=df.head(5000)

# %%
df
# Out:
#       Unnamed: 0      country  \
# 0              0        Italy
# 1              1     Portugal
# 2              2           US
# 3              3           US
# 4              4           US
# ...          ...          ...
# 4995        4995  New Zealand
# 4996        4996        Italy
# 4997        4997        Italy
# 4998        4998           US
# 4999        4999        Chile
#
#                                             description  \
# 0     Aromas include tropical fruit, broom, brimston...
# 1     This is ripe and fruity, a wine that is smooth...
# 2     Tart and snappy, the flavors of lime flesh and...
# 3     Pineapple rind, lemon pith and orange blossom ...
# 4     Much like the regular bottling from 2012, this...
# ...                                                 ...
# 4995  Sweaty and pungent, loaded with overtones of c...
# 4996  Here's a well-toasted red wine from Southern I...
# 4997  Candied fruit and caramel ride on the back of ...
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# Unnamed: 0                  0
# country                     3
# description                 0
# designation              1477
# points                      0
# price                     343
# province                    3
# region_1                  792
# region_2                 3044
# taster_name              1031
# taster_twitter_handle    1206
# title                       0
# variety                     0
# winery                      0
# dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# Unnamed: 0                  0
# country                     3
# description                 0
# designation              1477
# points                      0
# price                     343
# province                    3
# region_1                  792
# region_2                 3044
# taster_name              1031
# taster_twitter_handle    1206
# title                       0
# variety                     0
# winery                      0
# dtype: int64

# %%
df[['description','title']].fillna('', inplace=True)
# Out:
# <ipython-input-13-18af2c7ac150>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['description','title']].fillna('', inplace=True)

# %%
df[['description','title']].isnull().sum()
# Out:
# description    0
# title          0
# dtype: int64

# %%
tfidf=TfidfVectorizer(stop_words='english')

# %%
tfidf_m=tfidf.fit_transform(df['description'])
tfidf_m.shape
# Out:
# (5000, 8179)

# %%
cos_sim[0]
# Out:
# array([1.        , 0.01185855, 0.0100552 , ..., 0.00739211, 0.        ,
#        0.02650395])

# %%
cos_sim=cosine_similarity(tfidf_m,tfidf_m)

# %%
df['title']
df.index
# Out:
# RangeIndex(start=0, stop=5000, step=1)

# %%
cos_sim.shape
# Out:
# (5000, 5000)

# %%
data=dict(zip(df['title'],df.index))
i=data['Nicosia 2013 Vulkà Bianco  (Etna)']
print(i)
# Out:
# 0

# %%
def recommend(t,cosine_sim=cos_sim):     #t에는 제목 전달
  idx=data[t]
  sim_scores=list(enumerate(cosine_sim[idx]))
  ss=sorted(sim_scores, key=lambda x:x[1],reverse=True)
  ss=ss[1:11]
  res=[i[0] for i in ss]


  return df['title'].iloc[res]

# %%
recommend('Nicosia 2013 Vulkà Bianco  (Etna)')
# Out:
# 2000    Feudi del Pisciotto 2013 Baglio del Sole Inzol...
# 908                     Cascina Bruciata 2013  Barbaresco
# 1181              Bel Colle 2013 Montersino  (Barbaresco)
# 1036                  Vivera 2010 Salisire Bianco  (Etna)
# 4033    Chateau Ste. Michelle 2015 Horse Heaven Vineya...
# 904                         Boffa 2013 Pajè  (Barbaresco)
# 3414        Lechthaler 2014 Drago Pinot Grigio (Trentino)
# 4053    Cecilia Beretta 2011 Terre di Cariano Riserva ...
# 3908                     La Rajade 2014 Friulano (Collio)
# 677     Baracchi Riccardo 2011 Smeriglio Riserva Syrah...
# Name: title, dtype: object
